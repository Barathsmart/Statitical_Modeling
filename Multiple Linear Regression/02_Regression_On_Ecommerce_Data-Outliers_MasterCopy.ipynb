# %% [markdown]
# ## Business Problem

# %% [markdown]
# Ecommerce company based in a City that sells clothing online but they also have in-store style and clothing advice sessions.
# Customers come in to the store, have sessions/meetings with a personal stylist, then they can go home and order either on a mobile app or website for the clothes they want.
# The company is trying to <b> Decide whether to focus their efforts on their mobile app experience or their website. </b>

# %% [markdown]
# ## About the Data
#
# We'll work with the Ecommerce Customers csv file from the company. It has Customer info, suchas Email, Address, and their color Avatar. Then it also has numerical value columns:
#
# * Avg. Session Length: Average session of in-store style advice sessions.
# * Time on App: Average time spent on App in minutes
# * Time on Website: Average time spent on Website in minutes
# * Length of Membership: How many years the customer has been a member.
#
# ** Read in the Ecommerce Customers csv file as a DataFrame called customers.**

# %% [markdown]
# ## Loading the required modules
# ** Import pandas, numpy, matplotlib,and seaborn. Then set %matplotlib inline
# (You'll import sklearn as you need it.)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
from IPython.display import Image
warnings.filterwarnings('ignore')

# %%
customers = pd.read_csv("Ecommerce Customers.csv")

# %% [markdown]
# **Check the head of customers, and check out its info() and describe() methods.**

# %%
customers.shape # records and # columns
# Out:
# (500, 9)

# %%
customers.head(10) # snapshot of the data
# Out:
#                              Email  \
# 0                   kyang@diaz.org
# 1                 asilva@yahoo.com
# 2              william82@gmail.com
# 3  jeffrey54@mcdonald-williams.com
# 4               rhonda01@gmail.com
# 5           youngbarbara@yahoo.com
# 6        randyrobinson@hotmail.com
# 7            susanibarra@yahoo.com
# 8                 alicia85@lee.com
# 9            waltonkaren@gmail.com
#
#                                              Address      Avatar  \
# 0   223 Love Trail Suite 831\nPort Jeffrey, IN 46849   OliveDrab
# 1                         USNV Johnson\nFPO AP 19026       Wheat
# 2         11143 Park Squares\nSamanthatown, UT 97073  SandyBrown
# 3   297 Francis Valley\nSouth Lindsey, NY 13669-5367   Gainsboro
# 4          939 Watson Run\nStaceyberg, VT 58376-0454      Orchid
# 5  019 Elliott Tunnel Suite 190\nNicholsbury, WV ...       Wheat
# 6   14548 Hayes Isle Apt. 436\nGarciaville, IN 65366    DarkGray
# 7  426 Scott Radial Apt. 065\nAbigailstad, MS 165...     Thistle
# 8  14220 Carla Flat Suite 521\nLake Matthew, DE 0...     DimGray
# 9  355 Villegas Isle Apt. 070\nWest Jenniferview,...       Green
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.374258    15.126994        37.157624              5.377594
# 1            34.603311    12.207298        33.913847              6.922689
# 2            33.256335    13.858062        37.780265              5.976768
# 3            34.967610    13.919494        37.952013              5.066697
# 4            34.385820    12.729720        36.232110              5.705941
# 5            34.507551    12.893669        37.635756              5.705154
# 6            33.302672    13.459222        36.339521              5.566385
# 7            32.533240    14.121784        38.406329              5.320094
# 8            32.887105    12.387184        37.431159              6.401229
# 9            35.742670    10.889828        35.565436              6.115199
#
#    Yearly Amount Spent  Gender
# 0           765.518462  Female
# 1           744.221867    Male
# 2           725.584814    Male
# 3           712.396327  Female
# 4           708.935185  Female
# 5           700.917092    Male
# 6           689.787604  Female
# 7           689.235700  Female
# 8           684.163431    Male
# 9           669.987141  Female

# %%
customers.describe() # summary to understand the data, prints the summary only for numeric attributes by default
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           548.814038
# std                0.999278          1098.792971
# min                0.269901           266.086341
# 25%                2.930450           445.577927
# 50%                3.533975           500.120199
# 75%                4.126502           549.871479
# max                6.922689         25006.670580

# %%
customers.info() # To understand the data type for each of the variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
#  8   Gender                500 non-null    object
# dtypes: float64(5), object(4)
# memory usage: 35.3+ KB

# %%
customers.describe(include=['O'])
# Out:
#                      Email                                        Address  \
# count                  500                                            500
# unique                 500                                            500
# top     thomas22@yahoo.com  57120 Frank Keys\nJerryborough, DC 81028-0939
# freq                     1                                              1
#
#            Avatar Gender
# count         500    500
# unique        138      2
# top     CadetBlue   Male
# freq            7    260

# %% [markdown]
# ## Exploratory Data Analysis
#
# **Let's explore the data!**
#
# For the rest of the exercise we'll only be using the numerical data of the csv file.
# ___
# **Use Plotly to create a jointplot to compare the Time on Website and Yearly Amount Spent columns. Does the correlation make sense?**

# %%
import plotly.express as px

# %%
fig = px.scatter(customers, x="Avg. Session Length", y="Yearly Amount Spent")
fig.show()
# Out:
# <div>                            <div id="c5198149-3d68-4b40-933e-3b4ad1486305" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5198149-3d68-4b40-933e-3b4ad1486305")) {                    Plotly.newPlot(                        "c5198149-3d68-4b40-933e-3b4ad1486305",                        [{"hovertemplate": "Avg. Session Length=%{x}<br>Yearly Amount Spent=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [34.37425805, 34.60331112, 33.25633547, 34.96760989, 34.38582029, 34.507551, 33.30267221, 32.53323998, 32.88710465, 35.74266981, 34.48238805, 33.21547157, 33.17233109, 32.4071483, 33.24726795, 31.94539575, 34.40240965, 32.93133644, 33.55169914, 33.67275789, 35.03928306, 33.87103788, 33.08529799, 32.97518183, 33.89457039, 33.54047906, 32.0609144, 33.70815341, 33.54123131, 34.03416353, 33.87978429, 32.19249883, 33.10833615, 34.18382052, 32.22729914, 34.71331651, 33.61601855, 32.87847437, 33.26544447, 32.61785606, 32.64461691, 34.81498394, 33.33067252, 35.63085386, 33.41906735, 33.50136982, 34.33589584, 36.13966249, 32.03054972, 34.56455771, 33.76981237, 33.05926409, 34.46151474, 31.28344748, 33.63662446, 33.79203908, 34.00721197, 32.9925732, 32.17550124, 34.49726773, 33.62259184, 32.29464155, 34.31892744, 33.37401693, 34.50141785, 34.18818406, 35.4331653, 34.43642584, 34.30555663, 33.62530726, 34.19550803, 34.04663803, 33.87974497, 34.21146128, 33.08852937, 33.7016052, 33.45229528, 34
832111, 37.08792607, 38.768641, 36.68377615, 37.76304108, 36.80837606, 38.06341359, 39.25293095, 37.7436197, 36.77260376, 36.84473382, 35.99048895, 37.95968432, 36.63465233, 36.05024078, 36.35523488, 37.57016384, 37.38794554, 36.6338567, 36.65520808, 37.66110668, 35.63395395, 39.09462703, 37.25803146, 35.18912244, 37.55088041, 37.63731096, 37.96597162, 36.97937237, 36.81293413, 37.68487728, 38.61733445, 35.12882235, 37.05261631, 35.36862633, 39.07440021, 36.49399255, 38.3099079, 36.40774745, 37.06168877, 36.51734612, 36.54759628, 36.51838359, 38.44276669, 35.49396408, 36.1050005, 36.67822227, 37.23880567, 36.19975347, 37.26387556, 37.31770495, 35.26149812, 38.58585476, 38.42286529, 36.84149164, 37.37011822, 37.49669015, 37.63300942, 35.96889569, 36.77386137, 37.81915511, 36.83 ...

# %%
customers_clean = customers.drop(columns = ['Email','Address','Avatar'],axis=1)

# %%
sns.heatmap(customers.corr(),annot=True,cmap='Greens')

# %% [markdown]
# **Based on this plot what looks to be the most correlated feature with Yearly Amount Spent?**

# %%
# Length of Membership

# %% [markdown]
# **Create a linear model plot (using seaborn's lmplot) of  Yearly Amount Spent vs. Length of Membership. **

# %%
fig = px.scatter(customers, x="Length of Membership", y="Yearly Amount Spent",trendline="ols")
fig.show()
# Out:
# <div>                            <div id="49a759cc-7a5b-44fd-a595-b4cd9cccec6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49a759cc-7a5b-44fd-a595-b4cd9cccec6e")) {                    Plotly.newPlot(                        "49a759cc-7a5b-44fd-a595-b4cd9cccec6e",                        [{"hovertemplate": "Length of Membership=%{x}<br>Yearly Amount Spent=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [5.377593584, 6.922689335, 5.976768126, 5.066696864, 5.705940717, 5.705153971, 5.566384892, 5.320093864, 6.401228838, 6.115198946, 4.968742674, 5.840505876, 5.405406467, 5.039955264, 4.978475793, 6.076653638, 4.077775098, 5.485976734, 5.453969475, 4.794312263, 3.930615327, 5.493507201, 4.750360071, 4.297686524, 4.490002066, 5.007271987, 5.41235784, 3.634340224, 4.648199316, 3.605933918, 4.639320332, 5.049927475, 4.594116865, 4.252006106, 4.802630631, 4.632460946, 4.125584363, 4.693732058, 4.574287716, 4.06454855, 5.226687713, 4.389455226, 4.446308318, 4.019051427, 4.069916619, 4.130562809, 4.694322274, 3.864860739, 5.038107494, 3.876875177, 5.137816746, 5.004820577, 4.350887844, 5.000243361, 5.254708926, 4.214495086, 4.330714462, 4.620416385, 4.343062915, 4.082620633, 5.462500764, 5.084861309, 3.606086889, 5.454463278, 4.008352235, 3.790552137, 4.000963586, 3.371258113, 3.120178783, 3.969417759, 4.330407444, 4.055775962, 3.258112883, 4.985204971, 4.806349619, 4.716104987, 4.712233579, 3.292797663, 4.615426307, 4.029453828, 3.792711955, 4.652854446, 3.746572973, 3.918541839, 4.920318406, 4.297737482, 3.798725319, 3.762070443, 4.664258497, 3.854473856, 3.273433578, 4.541695257, 4.25698329, 4.158214653, 3.515688256, 4.113226123, 5.314354141, 4.746989703, 4.195614413, 4.051382465, 4.478712608, 4.559699083, 4.20590389, 4.543332413, 2.90900846, 4.729484542, 3.772969025, 3.230973843, 4.626075292, 3.738225173, 4.595522709, 5.391275125, 4.003325039, 4.087837273, 4.74257752, 3.784273087, 3.701622287, 4.001786346, 3.905250309, 4.958264473, 4.183143662, 3.046540621, 4.520353377, 4.434273435, 3.663105491, 4.662845304, 3.318822279, 3.97452248, 3.283663455, 3.488029991, 3.970555628, 4.64325855, 3.345922321, 4.571213024, 4.403369831, 3.416209978, 4.369366794, 4.470282584, 4.560396067, 3.8710034, 3.130538462, 4.131276648, 3.229450904, 3.569046516, 4.531986607, 4.041244969, 3.275733705, 3.462298847, 3.310150347, 5.023934201, 4.198349061, 4.222436225, 4.082855279, 4.13175504, 3.597459969, 5.113319475, 3.768561963, 3.843848921, 3.827375915, 4.301996499, 3.8515788, 3.47202138, 4.599937358, 4.396651901, 4.808320373, 3.689916615, 3.641497162, 4.671275461, 4.334001444, 4.773503047, 4.048510087, 5.047022551, 4.02210291, 2.871947536, 3.923488746, 3.89711586, 3.937862643, 2.685284836, 3.576525915, 4.852842407, 2.935577274, 3.680847338, 3.78493211, 3.228717686, 3.137068975, 2.907094935, 4.789201624, 3.982471513, 2.87459691, 3.713209203, 3.649286158, 4.685017247, 4.778973636, 4.027813842, 4.081802695, 2.995761183, 3.678589399, 3.919302309, 3.634996006, 3.184618662, 4.72402744, 4.106055152, 3.997255378, 3.447017793, 3.834169667, 4.01872661, 4.193324636, 3.456233824, 3.6758488, 4.331863027, 3.60439856, 3.397363093, 4.349778419, 3.086337272, 4.137000388, 2.768851943, 4.129254688, 3.447092896, 3.163091931, 4.116340467, 3.481062133, 3.90447938, 4.124585297, 3.911708668, 5.081210092, 3.873337569, 3.015175299, 3.802511439, 3.45175071, 2.957448757, 3.345570976, 4.243812817, 4.01598664, 3.917451119, 1.920715478, 2.941410754, 3.557813698, 3.373104674, 3.336339382, 4.03438613, 3.89289148, 3.3766875, 3.612239152, 3.467014066, 4.646119977, 4.717102513, 3.634093727, 2.964497876, 3.442799202, 3.54 ...

# %% [markdown]
# ## Dealing with Categorical Variables

# %%
customers_clean = pd.get_dummies(data=customers_clean, drop_first=True,dtype='int8')

# %%
customers_clean.head()
# Out:
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.374258    15.126994        37.157624              5.377594
# 1            34.603311    12.207298        33.913847              6.922689
# 2            33.256335    13.858062        37.780265              5.976768
# 3            34.967610    13.919494        37.952013              5.066697
# 4            34.385820    12.729720        36.232110              5.705941
#
#    Yearly Amount Spent  Gender_Male
# 0           765.518462            0
# 1           744.221867            1
# 2           725.584814            1
# 3           712.396327            0
# 4           708.935185            0

# %% [markdown]
# ## Data Preparation for model building
#
# Now that we've explored the data a bit, let's go ahead and split the data into training and testing sets.
# ** Set a variable X equal to the numerical features of the customers and a variable y equal to the "Yearly Amount Spent" column. **

# %%
customers_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Avg. Session Length   500 non-null    float64
#  1   Time on App           500 non-null    float64
#  2   Time on Website       500 non-null    float64
#  3   Length of Membership  500 non-null    float64
#  4   Yearly Amount Spent   500 non-null    float64
#  5   Gender_Male           500 non-null    int8
# dtypes: float64(5), int8(1)
# memory usage: 20.1 KB

# %%
X = customers_clean.drop(['Yearly Amount Spent'],axis=1)

# %%
y = customers_clean['Yearly Amount Spent']

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %% [markdown]
# ** Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Set test_size=0.3 and random_state=101**

# %% [markdown]
# ## Spilit the data into Training and Testing Data

# %%
Image('train_test_Split.png',height=800 , width=600)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
len(y_train)
print('Y Target Size:', len(y_train))
print('X Train Size:', len(X_train))
print('X Test  Size:', len(X_test))
print('Y Target Size:', len(y_test))
# Out:
# Y Target Size: 400
# X Train Size: 400
# X Test  Size: 100
# Y Target Size: 100

# %%
# adding the Constant term
X_reg = sm.add_constant(X_train)
X_reg.head()
# Out:
#      const  Avg. Session Length  Time on App  Time on Website  \
# 161    1.0            33.119954    12.953263        37.034280
# 72     1.0            33.879745    13.587806        38.260353
# 246    1.0            33.177205    11.622777        35.968896
# 230    1.0            33.477190    12.488067        36.518384
# 391    1.0            31.864833    13.443406        36.878315
#
#      Length of Membership  Gender_Male
# 161              3.472021            0
# 72               3.258113            0
# 246              3.634094            0
# 230              3.345571            0
# 391              2.361087            1

# %%
y_train[:5]
# Out:
# 161    534.771485
# 72     578.241605
# 246    501.209173
# 230    505.771140
# 391    439.891280
# Name: Yearly Amount Spent, dtype: float64

# %% [markdown]
# ## Training the Model
#
# Now its time to train our model on our training data!

# %% [markdown]
# ## Multiple Regression model - R style

# %%
model = sm.OLS(y_train, X_reg)
results = model.fit()
print(results.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Yearly Amount Spent   R-squared:                       0.020
# Model:                             OLS   Adj. R-squared:                  0.008
# Method:                  Least Squares   F-statistic:                     1.623
# Date:                 Thu, 24 Mar 2022   Prob (F-statistic):              0.153
# Time:                         17:13:00   Log-Likelihood:                -3408.2
# No. Observations:                  400   AIC:                             6828.
# Df Residuals:                      394   BIC:                             6852.
# Df Model:                            5
# Covariance Type:             nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 5737.1884   3453.522      1.661      0.097   -1052.447    1.25e+04
# Avg. Session Length    -23.6241     65.261     -0.362      0.718    -151.927     104.678
# Time on App           -112.2111     67.022     -1.674      0.095    -243.977      19.555
# Time on Website        -59.7790     60.866     -0.982      0.327    -179.441      59.883
# Length of Membership  -190.0925     77.732     -2.445      0.015    -342.915     -37.270
# Gender_Male           -310.1598    174.397     -1.778      0.076    -653.025      32.706
# ==============================================================================
# Omnibus:                      933.944   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2273369.188
# Skew:                          18.876   Prob(JB):                         0.00
# Kurtosis:                     370.392   Cond. No.                     2.90e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.9e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Check for Linearity

# %%
from scipy import stats

# %%
f = plt.figure(figsize=(14,5))
ax = f.add_subplot(221)
sns.scatterplot(y_train,results.fittedvalues,ax=ax,color='r')
ax.set_title('Check for Linearity:\n Actual Vs Predicted value')

std_residuals = stats.zscore(y_train-results.fittedvalues)
f = plt.figure(figsize=(14,5))
ax = f.add_subplot(222)
sns.scatterplot(results.fittedvalues,std_residuals,ax=ax,color='g')
ax.set_title('Check for Linearity:\n Predicted value Vs Std.Residuals')



# Check for Residual normality & mean
ax = f.add_subplot(223)
sns.distplot((y_train - results.fittedvalues),ax=ax,color='b')
ax.axvline((y_train - results.fittedvalues).mean(),color='k',linestyle='--')
ax.set_title('Check for Residual normality & mean: \n Residual eror');

# %% [markdown]
# ## Residuals - QQ Plot
#
# You should have gotten a very good model with a good fit. Let's quickly explore the residuals to make sure everything was okay with our data.
#
# **Plot a histogram of the residuals and make sure it looks normally distributed. Use either seaborn distplot, or just plt.hist().**

# %%
sm.qqplot(results.resid, line='s')

# %% [markdown]
# ## Influential points

# %%
from statsmodels.stats.outliers_influence import OLSInfluence

# %%
influence_points = OLSInfluence(results) # results is output from the lm model built earlier

pd.DataFrame(influence_points.influence).describe()
# Out:
#                 0
# count  400.000000
# mean     1.879549
# std     47.423269
# min    -47.966569
# 25%     -2.205530
# 50%     -0.544450
# 75%      0.708627
# max    932.247781

# %%
influence_data = pd.DataFrame(influence_points.influence[influence_points.influence>=10])
customers_clean['influence_value']= influence_points.influence
customers_clean.loc[influence_data.index,].sort_values(['influence_value'], ascending = False).head(10)
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 499            32.836941    10.256549        36.143908              0.789520
# 1              34.603311    12.207298        33.913847              6.922689
# 5              34.507551    12.893669        37.635756              5.705154
# 0              34.374258    15.126994        37.157624              5.377594
# 11             33.215472    12.135101        37.142094              5.840506
# 16             34.402410    14.220979        37.523197              4.077775
# 21             33.871038    12.026925        34.476878              5.493507
# 25             33.540479    12.884125        36.226042              5.007272
# 3              34.967610    13.919494        37.952013              5.066697
# 7              32.533240    14.121784        38.406329              5.320094
#
#      Yearly Amount Spent  Gender_Male  influence_value
# 499         25006.670580            1       932.247781
# 1             744.221867            1       103.141658
# 5             700.917092            1        57.076581
# 0             765.518462            0        38.217472
# 11            663.803693            1        31.923832
# 16            647.619456            1        31.901354
# 21            637.102448            1        25.510308
# 25            628.047804            1        20.022987
# 3             712.396327            0        19.330839
# 7             689.235700            0        17.240197

# %%
from statsmodels.graphics.regressionplots import plot_leverage_resid2
fig, ax = plt.subplots(figsize=(8, 6))
fig = plot_leverage_resid2(results, ax=ax)

# %%
customers_clean.loc[[0,1,499]]
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0              34.374258    15.126994        37.157624              5.377594
# 1              34.603311    12.207298        33.913847              6.922689
# 499            32.836941    10.256549        36.143908              0.789520
#
#      Yearly Amount Spent  Gender_Male  influence_value
# 0             765.518462            0        38.217472
# 1             744.221867            1       103.141658
# 499         25006.670580            1       932.247781

# %% [markdown]
# ## Model Evaluation : Error metrics
#
# Let's evaluate our model performance by calculating the residual sum of squares and the explained variance score (R^2).
#
# ** Calculate the Mean Absolute Error, Mean Squared Error, and the Root Mean Squared Error. Refer to the lecture or to Wikipedia for the formulas**

# %%
# calculate these metrics by hand!
from sklearn import metrics

print('MAE Train:', metrics.mean_absolute_error(y_train, results.fittedvalues))
print('MSE Train:', metrics.mean_squared_error(y_train, results.fittedvalues))
print('RMSE Train:', np.sqrt(metrics.mean_squared_error(y_train, results.fittedvalues)))
# Out:
# MAE Train: 229.72431971766963
# MSE Train: 1473729.9664432302
# RMSE Train: 1213.9728030080535

# %% [markdown]
# ### Handling the outliers and Infleuntial points

# %%
customers_clean1 = customers_clean[customers_clean.influence_value<=10]

# %%
print('Data Size before removing outliers {}'.format(customers_clean.shape))
print('Date Size after removing outliers {}'.format(customers_clean1.shape))
# Out:
# Data Size before removing outliers (500, 7)
# Date Size after removing outliers (385, 7)

# %%
customers_clean1.head()
# Out:
#     Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 10            34.482388    13.283033        35.907298              4.968743
# 13            32.407148    13.808799        37.426769              5.039955
# 17            32.931336    12.732212        35.600821              5.485977
# 20            35.039283    14.426491        37.374184              3.930615
# 22            33.085298    13.093537        38.315648              4.750360
#
#     Yearly Amount Spent  Gender_Male  influence_value
# 10           666.125592            0         6.691685
# 13           662.961088            0         7.861432
# 17           642.101579            0         5.393969
# 20           640.187740            0         9.531983
# 22           632.123588            0         4.412076

# %%
X = customers_clean1.drop(['Yearly Amount Spent','influence_value'],axis=1)
y = customers_clean1['Yearly Amount Spent']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)
# adding the Constant term
X_reg = sm.add_constant(X_train)
X_reg.head()

X_test = sm.add_constant(X_test)

# %%
model = sm.OLS(y_train, X_reg)
results = model.fit()
print(results.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Yearly Amount Spent   R-squared:                       0.982
# Model:                             OLS   Adj. R-squared:                  0.982
# Method:                  Least Squares   F-statistic:                     3290.
# Date:                 Thu, 24 Mar 2022   Prob (F-statistic):          6.14e-261
# Time:                         17:18:48   Log-Likelihood:                -1135.3
# No. Observations:                  308   AIC:                             2283.
# Df Residuals:                      302   BIC:                             2305.
# Df Model:                            5
# Covariance Type:             nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 -976.9741     32.986    -29.618      0.000   -1041.886    -912.062
# Avg. Session Length     24.2412      0.631     38.416      0.000      22.999      25.483
# Time on App             37.6057      0.683     55.020      0.000      36.261      38.951
# Time on Website          0.4140      0.561      0.738      0.461      -0.690       1.518
# Length of Membership    59.2908      0.857     69.149      0.000      57.604      60.978
# Gender_Male             -6.5252      1.824     -3.577      0.000     -10.115      -2.935
# ==============================================================================
# Omnibus:                        0.426   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.808   Jarque-Bera (JB):                0.447
# Skew:                          -0.089   Prob(JB):                        0.800
# Kurtosis:                       2.945   Cond. No.                     3.04e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from scipy import stats

# %%
f = plt.figure(figsize=(14,5))
ax = f.add_subplot(221)
sns.scatterplot(y_train,results.fittedvalues,ax=ax,color='r')
ax.set_title('Check for Linearity:\n Actual Vs Predicted value')

std_residuals = stats.zscore(y_train-results.fittedvalues)
f = plt.figure(figsize=(14,5))
ax = f.add_subplot(222)
sns.scatterplot(results.fittedvalues,std_residuals,ax=ax,color='g')
ax.set_title('Check for Linearity:\n Predicted value Vs Std.Residuals')



# Check for Residual normality & mean
ax = f.add_subplot(223)
sns.distplot((y_train - results.fittedvalues),ax=ax,color='b')
ax.axvline((y_train - results.fittedvalues).mean(),color='k',linestyle='--')
ax.set_title('Check for Residual normality & mean: \n Residual eror');

# %%
# calculate these metrics by hand!
from sklearn import metrics

def error_metrics(train_act,train_pred,test_act,test_pred):
        
        print('*** Error metrics Train data ***')
        print('MAE Train:', metrics.mean_absolute_error(train_act, train_pred))
        print('MSE Train:', metrics.mean_squared_error(train_act, train_pred))
        print('RMSE Train:', np.sqrt(metrics.mean_squared_error(train_act, train_pred)))
        print('MAPE Train:', metrics.mean_absolute_percentage_error(train_act, train_pred))

        print('***\n Error metrics Test Data ***')

        print('MAE Train:', metrics.mean_absolute_error(test_act,test_pred))
        print('MSE Train:', metrics.mean_squared_error(test_act,test_pred))
        print('RMSE Train:', np.sqrt(metrics.mean_squared_error(test_act,test_pred)))
        print('MAPE Train:', metrics.mean_absolute_percentage_error(test_act,test_pred))

# %%
test_fitted_values
# Out:
# 257    478.731357
# 214    509.158114
# 197    506.633031
# 488    328.546464
# 80     582.625532
#           ...
# 87     574.906752
# 338    461.935858
# 365    437.836877
# 163    527.536166
# 413    431.962411
# Length: 77, dtype: float64

# %%
test_fitted_values = results.predict(X_test)

# %%
results.fittedvalues
# Out:
# 232    513.919623
# 451    421.452149
# 380    464.257760
# 261    494.312995
# 103    569.493163
#           ...
# 94     573.513078
# 427    425.744472
# 443    417.724723
# 34     621.010643
# 459    389.445115
# Length: 308, dtype: float64

# %%
test_fitted_values
# Out:
# 257    478.731357
# 214    509.158114
# 197    506.633031
# 488    328.546464
# 80     582.625532
#           ...
# 87     574.906752
# 338    461.935858
# 365    437.836877
# 163    527.536166
# 413    431.962411
# Length: 77, dtype: float64

# %%
error_metrics(y_train,results.fittedvalues,y_test,test_fitted_values)
# Out:
# *** Error metrics Train data ***
# MAE Train: 7.706427547415086
# MSE Train: 93.16677611942889
# RMSE Train: 9.65229382682836
# MAPE Train: 0.016091635185176156
# ***
#  Error metrics Test Data ***
# MAE Train: 8.292932674896171
# MSE Train: 102.66301217646625
# RMSE Train: 10.132275764924001
# MAPE Train: 0.01726163850458025

# %% [markdown]
# ## Standardizing the data

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = StandardScaler()

# %%
num_vars = ['Avg. Session Length', 'Time on App', 'Time on Website',
       'Length of Membership']

# %%
X = customers_clean1.drop(['Yearly Amount Spent','influence_value'],axis=1)

# %%
y = customers_clean1['Yearly Amount Spent']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
X_train[num_vars] = scaler.fit_transform(X_train[num_vars])
X_test[num_vars] = scaler.fit_transform(X_test[num_vars])

# %%
# adding the Constant term
X_reg = sm.add_constant(X_train)
X_reg.head()
# Out:
#      const  Avg. Session Length  Time on App  Time on Website  \
# 232    1.0             0.640389    -0.818373        -1.559405
# 451    1.0             1.554709    -0.240155         1.091997
# 380    1.0             0.809229    -0.486617        -1.112145
# 261    1.0             0.860222     0.281613        -0.470599
# 103    1.0             0.496674    -0.059197        -1.150208
#
#      Length of Membership  Gender_Male
# 232              0.594869            0
# 451             -1.741790            1
# 380             -0.472727            1
# 261             -0.461612            1
# 103              1.156203            0

# %% [markdown]
# ## Model coefficients

# %%
coeffecients = pd.DataFrame(results.params,results.model.exog_names)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#                       Coeffecient
# const                 -976.974101
# Avg. Session Length     24.241209
# Time on App             37.605722
# Time on Website          0.413959
# Length of Membership    59.290820
# Gender_Male             -6.525199

# %% [markdown]
# ## Visualizing the model coefficients

# %%
coeff = results.params
coeff = coeff.iloc[(coeff.abs()*-1.0).argsort()]
sns.barplot(x=coeff.values, y=coeff.index, orient='h');
