# %% [markdown]
# # PCA
#  * Principal Component Analysis
#  * PCA! Since this isn't exactly a full machine learning algorithm.
#  * This is a Dimensionality reduction Technique
#  * this is comes under EDA process
#  * use PCA only for numeric variables
#  * this is not Feature Eliminiation Technique Feature reduction technique

# %% [markdown]
# as we incerease a number of dimension keeping sample size same it increase the model performence at some point but after it will decrease
#
# create new set of coordinates for data
# reveals internel structure of a data which explains most variancee
# reduce dimensionality of multivariate data
#
#
# why we need to move center ?
# our data is spread across for
# we han't change the data just moved it to center
#
#
# well well well one good load of combined statistics ,matha matics,dimensionlity ..for buliding a mL model

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import load_breast_cancer

# %%
lbc=load_breast_cancer()

# %%
x=pd.DataFrame(lbc['data'],columns=lbc['feature_names'])
y=pd.DataFrame(lbc['target'],columns=['type'])

# %%
x
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
y
# Out:
#      type
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# ..    ...
# 564     0
# 565     0
# 566     0
# 567     0
# 568     1
#
# [569 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1234,stratify=y)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
predict=lr.predict(x_test)
# Out:
# C:\Users\Barath Murugan\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Barath Murugan\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import confusion_matrix
cm1=confusion_matrix(y_test,predict)
score=lr.score(x_test,y_test)

# %%
cm1
# Out:
# array([[ 56,   8],
#        [  5, 102]], dtype=int64)

# %%
score
# Out:
# 0.9239766081871345

# %% [raw]
# #pca

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_scale=scaler.fit_transform(x)

# %%
x
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
x_scale
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %%
# Out:
# C:\Users\Barath Murugan\AppData\Local\Temp\ipykernel_35056\3211340904.py:1: RuntimeWarning: Mean of empty slice.
#   x_scale[:0].mean()
# C:\Users\Barath Murugan\anaconda3\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# nan

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
x_pca = pca.fit_transform(x_scale)

# %%
x_pca
# Out:
# array([[ 9.19283683e+00,  1.94858307e+00, -1.12316616e+00, ...,
#         -3.39144536e-02,  4.56477199e-02, -4.71692081e-02],
#        [ 2.38780180e+00, -3.76817174e+00, -5.29292687e-01, ...,
#          3.26241827e-02, -5.68742432e-03, -1.86787626e-03],
#        [ 5.73389628e+00, -1.07517380e+00, -5.51747593e-01, ...,
#          4.70258247e-02,  3.14589659e-03,  7.50534755e-04],
#        ...,
#        [ 1.25617928e+00, -1.90229671e+00,  5.62730526e-01, ...,
#         -2.57775589e-03,  6.70621179e-03,  3.77041667e-03],
#        [ 1.03747941e+01,  1.67201011e+00, -1.87702933e+00, ...,
#         -6.80863833e-02, -8.41632764e-02, -2.37828222e-02],
#        [-5.47524330e+00, -6.70636791e-01,  1.49044308e+00, ...,
#         -9.51587894e-03, -6.09131090e-02, -1.94755854e-02]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x_pca,y,test_size=0.3,random_state=1234,stratify=y)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
predict=lr.predict(x_test)
# Out:
# C:\Users\Barath Murugan\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.metrics import confusion_matrix
cm1=confusion_matrix(y_test,predict)
score=lr.score(x_test,y_test)

# %%
cm1
# Out:
# array([[ 63,   1],
#        [  1, 106]], dtype=int64)

# %%
score
# Out:
# 0.9883040935672515

# %%
pca.explained_variance_ratio_
# Out:
# array([4.42720256e-01, 1.89711820e-01, 9.39316326e-02, 6.60213492e-02,
#        5.49576849e-02, 4.02452204e-02, 2.25073371e-02, 1.58872380e-02,
#        1.38964937e-02, 1.16897819e-02, 9.79718988e-03, 8.70537901e-03,
#        8.04524987e-03, 5.23365745e-03, 3.13783217e-03, 2.66209337e-03,
#        1.97996793e-03, 1.75395945e-03, 1.64925306e-03, 1.03864675e-03,
#        9.99096464e-04, 9.14646751e-04, 8.11361259e-04, 6.01833567e-04,
#        5.16042379e-04, 2.72587995e-04, 2.30015463e-04, 5.29779290e-05,
#        2.49601032e-05, 4.43482743e-06])

# %%
#screen plot
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of required components')
plt.ylabel("Explained varience ratio")
# Out:
# Text(0, 0.5, 'Explained varience ratio')
